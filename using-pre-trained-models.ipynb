# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.restnet50 import preprocess_input,decode_predictions
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from tensorflow.keras.applications.resnet50 import ResNet50
#       2 from tensorflow.keras.preprocessing import image
# ----> 3 from tensorflow.keras.applications.restnet50 import preprocess_input,decode_predictions
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'tensorflow.keras.applications.restnet50'

# %%
model=ResNet(weights='imagenet')

# %%
img_path=''
img=image.load_img(img_path,target_size=(224,234))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(
